# %% [markdown]
# # Sentiment Analysis for Long Text
#
# Sentiment analysis, also known as opinion mining, is a computational technique that involves the use of natural language processing, machine learning, and statistical methods to analyze and determine the emotional tone, attitudes, and opinions expressed in textual data. In an era dominated by vast amounts of user-generated content on social media, reviews, and other online platforms, sentiment analysis has emerged as a crucial tool for understanding and extracting valuable insights from the immense volume of textual information.
#
# The primary objective of sentiment analysis is to classify the sentiment conveyed in a piece of text as positive, negative, or neutral. This enables businesses, researchers, and organizations to gain a deeper understanding of public opinion, customer feedback, and overall sentiment towards products, services, brands, or any other subject of interest. By automating the process of sentiment analysis, it becomes possible to efficiently process and make sense of large datasets, enabling timely and informed decision-making.
#
# Sentiment analysis finds application in various domains, including marketing, customer service, product development, political analysis, and social research. Its versatility makes it a valuable tool for businesses aiming to enhance customer satisfaction, monitor brand perception, and stay attuned to market trends. As technology continues to advance, sentiment analysis methods evolve to handle the complexities of language, cultural nuances, and the dynamic nature of online communication.
#
# Most methods of sentiment analysis involves using supervised learning. Sentiment analysis using supervised learning is an approach that involves training a machine learning model on a labeled dataset to predict the sentiment of text. In this context, "supervised learning" refers to the training process where the model is provided with a dataset containing examples of text along with their corresponding sentiment labels (e.g., positive, negative, or neutral). The model learns patterns and relationships within the labeled data, enabling it to make predictions on new, unseen text.
#
# However, datasets with sentiment labels for longs texts are not readily available on the internet. Therefore, our project focuses on fixing this issue by creating a system where sentiment analysis can be performed on long text.

# %% [markdown]
# ## Sentiment analysis using unsupervised learning
#
# Therefore, we created a system where we can use unsupervised learning to do sentiment analysis.

# %% [markdown]
# ### First, we import the necessary libraries

# %%
# data processing and Data manipulation
import numpy as np # linear algebra
import pandas as pd # data processing

import sklearn
from sklearn.model_selection import train_test_split
    
# Libraries and packages for NLP
import nltk
import gensim
from gensim.models import Word2Vec

import os
import sys
import warnings
if not sys.warnoptions:
    warnings.simplefilter("ignore")
    
print('*** --> Modules are imported: ')    
print("Python version:", sys.version)
print("numpy version:", np.__version__)
print("pandas version:", pd.__version__)

print("sklearn version:", sklearn.__version__)
print("nltk version:", nltk.__version__)
print("gensim version:", gensim.__version__)
# Out:
# *** --> Modules are imported:
# Python version: 3.7.16 (default, Jan 17 2023, 22:20:44)
# [GCC 11.2.0]
# numpy version: 1.17.4
# pandas version: 1.3.5
# sklearn version: 1.0.2
# nltk version: 3.8.1
# gensim version: 4.2.0

# %% [markdown]
# ### Then, we read the data that we want to perform sentiment analysis on

# %%
# Importing IMDB Data from data directory which is two directory uper than the current directory
data_path = os.path.abspath(os.path.join(os.pardir,
                                         os.pardir, 
                                         'data/clean_news_1.csv'))
df = pd.read_csv(data_path, dtype={'news_body': str})
# df.head(3)
df
# Out:
#                                             news_body
# 0   (Bloomberg) -- With just three weeks to go, 20...
# 1   Investing.com – Colombia stocks were higher af...
# 2   Investing.com – Canada stocks were lower after...
# 3   WASHINGTON (Reuters) - Three U.S. senators on ...
# 4   (Bloomberg) -- U.S. investors looking to get i...
# ..                                                ...
# 95  Investing.com – Sweden stocks were lower after...
# 96  TEL AVIV (Reuters) - Salesforce.com (N:CRM) is...
# 97  Investing.com – Saudi Arabia stocks were lower...
# 98  By Stephanie Nebehay and Ryan WooGENEVA/BEIJIN...
# 99  Investing.com – Canada stocks were lower after...
#
# [100 rows x 1 columns]

# %% [markdown]
# ### We now perform preprocessing on the code.
#
# Sentence preprocessing is a crucial step in preparing textual data for machine learning tasks, including natural language processing (NLP) and sentiment analysis. The goal is to transform raw text into a format that machine learning models can effectively understand and process.

# %%
# Adding `src` directory to the directories for interpreter to search
sys.path.append(os.path.abspath(os.path.join('../..','Model/src')))

# Importing functions and classes from utility module
from w2v_utils import (Tokenizer,
                       evaluate_model,
                       bow_vectorizer,
                       train_logistic_regressor,
                       w2v_trainer,
                       calculate_overall_similarity_score,
                       overall_semantic_sentiment_analysis,
                       list_similarity,
                       calculate_topn_similarity_score,
                       topn_semantic_sentiment_analysis,
                       define_complexity_subjectivity_reviews,
                       explore_high_complexity_reviews,
                       explore_low_subjectivity_reviews,
                       text_SSA)

# %%
# Instancing the Tokenizer class
tokenizer = Tokenizer(clean= True,
                      lower= True, 
                      de_noise= True, 
                      remove_stop_words= True,
                      keep_negation=True)

# Example statement
statement = "I didn't like this movie. It wasn't amusing nor visually interesting . I do not recommend it."
print(tokenizer.tokenize(statement))
# Out:
# ['NOTlike', 'movie', 'NOTamusing', 'visually', 'interesting', 'NOTrecommend']

# %%
# Tokenize reviews
df['tokenized_text'] = df['news_body'].astype(str).apply(tokenizer.tokenize)

df['tokenized_text_len'] = df['tokenized_text'].apply(len)
df['tokenized_text_len'].apply(np.log).describe()
# Out:
# count    100.000000
# mean       5.372366
# std        0.625784
# min        3.091042
# 25%        5.020437
# 50%        5.427148
# 75%        5.733326
# max        6.658011
# Name: tokenized_text_len, dtype: float64

# %%
df.at[0,"tokenized_text"]
# Out:
# ['bloomberg',
#  'three',
#  'weeks',
#  'go',
#  '2018',
#  'market',
#  'contrarians',
#  'proving',
#  'prescient',
#  'outlook',
#  'decidedly',
#  'bullish',
#  'u',
#  'stocks',
#  'developing',
#  'nation',
#  'assets',
#  '12',
#  'months',
#  'ago',
#  'forecast',
#  'build',
#  'upon',
#  'stellar',
#  '2017',
#  'beaten',
#  'greenback',
#  'expected',
#  'fare',
#  'better',
#  '2018',
#  'rosy',
#  'international',
#  'growth',
#  'outlook',
#  'threatened',
#  'lure',
#  'investors',
#  'away',
#  'american',
#  'markets',
#  'despite',
#  'tough',
#  'talk',
#  'u',
#  'china',
#  'risks',
#  'trade',
#  'war',
#  'afterthought',
#  'NOTmuch',
#  'gone',
#  'according',
#  'plan',
#  'dws',
#  'cantor',
#  'fitzgerald',
#  'morgan',
#  'stanley',
#  'nyse',
#  'ms',
#  'among',
#  'bet',
#  'trend',
#  'got',
#  'right',
#  'federal',
#  'reserve',
#  'rate',
#  'hikes',
#  'backdrop',
#  'sharply',
#  'escalating',
#  'trade',
#  'tensions',
#  'roiled',
#  'markets',
#  '2018',
#  'punishing',
#  'u',
#  'stocks',
#  'causing',
#  'risk',
#  'averse',
#  'investors',
#  'flee',
#  'developing',
#  'nations',
#  'meanwhile',
#  'dollar',
#  'gained',
#  'virtually',
#  'major',
#  'currencies',
#  'amid',
#  'rising',
#  'rates',
#  'buoyant',
#  'u',
#  'growth',
#  'called',
#  '2018',
#  'correctly',
#  'expect',
#  'new',
#  'year',
#  'stalling',
#  'dollarstefanie',
#  'holtze',
#  'jen',
#  'chief',
#  'currency',
#  'strategist',
#  'asset',
#  'manager',
#  'dws',
#  'among',
#  'vindicated',
#  'february',
#  'dollar',
#  'worst',
#  'annual',
#  'slide',
#  '14',
#  'years',
#  'called',
#  'greenback',
#  'strengthen',
#  '1',
#  '15',
#  'per',
#  'euro',
#  'march',
#  '2019',
#  'prevailing',
#  'level',
#  '1',
#  '23',
#  'argument',
#  'u',
#  'twin',
#  'deficits',
#  'would',
#  'depress',
#  'dollar',
#  'hyped',
#  'according',
#  'holtze',
#  'jen',
#  'saw',
#  'extreme',
#  'bearish',
#  'positioning',
#  'setting',
#  'rebound',
#  'dollar',
#  'rally',
#  'starting',
#  'mid',
#  'april',
#  'proved',
#  'right',
#  'inflicting',
#  'pain',
#  'global',
#  'investors',
#  'holtze',
#  'jen',
#  'expect',
#  'another',
#  'strong',
#  'year',
#  'greenback',
#  'sees',
#  'euro',
#  'ending',
#  'next',
#  'year',
#  '1',
#  '15',
#  'slowing',
#  'growth',
#  'european',
#  'political',
#  'woes',
#  'weigh',
#  'common',
#  'currency',
#  'fed',
#  'approaches',
#  'end',
#  'hiking',
#  'cycle',
#  'expectations',
#  'fed',
#  'rate',
#  'increases',
#  'crumbled',
#  'markets',
#  'pricing',
#  'less',
#  'quarter',
#  'point',
#  'tightening',
#  '2019',
#  'forecasters',
#  'expect',
#  'euro',
#  'dollar',
#  'pair',
#  'reach',
#  '1',
#  '20',
#  'end',
#  '2019',
#  'according',
#  'bloomberg',
#  'survey',
#  '1',
#  '14',
#  'fed',
#  'come',
#  'back',
#  'autopilot',
#  'said',
#  'holtze',
#  'jen',
#  'calls',
#  'data',
#  'dependent',
#  'something',
#  'takes',
#  'needle',
#  'lower',
#  'dollar',
#  'going',
#  'forward',
#  'u',
#  'equities',
#  'gloomwhen',
#  'comes',
#  'u',
#  'stocks',
#  '2018',
#  'bears',
#  'still',
#  'skeptical',
#  'months',
#  'cantor',
#  'fitzgerald',
#  'peter',
#  'cecchini',
#  'forecast',
#  'p',
#  '500',
#  'finish',
#  'year',
#  '2',
#  '805',
#  'one',
#  'bearish',
#  'projections',
#  'among',
#  'wall',
#  'street',
#  'strategists',
#  'almost',
#  '7',
#  'percent',
#  'friday',
#  'close',
#  'deceleration',
#  'u',
#  'growth',
#  'driven',
#  'part',
#  'higher',
#  'funding',
#  'costs',
#  'tighter',
#  'financial',
#  'conditions',
#  'frothy',
#  'commercial',
#  'industrial',
#  'loan',
#  'market',
#  'create',
#  'credit',
#  'stress',
#  'next',
#  'year',
#  'according',
#  'cecchini',
#  'disposition',
#  'towards',
#  'equities',
#  'moved',
#  'buy',
#  'dip',
#  'sell',
#  'rally',
#  'said',
#  'cecchini',
#  'cantor',
#  'chief',
#  'global',
#  'market',
#  'strategist',
#  'NOTconstructive',
#  'credit',
#  'markets',
#  'constructive',
#  'equity',
#  'markets',
#  'company',
#  'pessimism',
#  'morgan',
#  'stanley',
#  'mike',
#  'wilson',
#  'biggest',
#  'equity',
#  'bear',
#  'wall',
#  'street',
#  'forecast',
#  'last',
#  'month',
#  'p',
#  '500',
#  'end',
#  '2019',
#  '2',
#  '750',
#  'target',
#  'called',
#  'year',
#  'fiscal',
#  'boost',
#  'tax',
#  'cuts',
#  'wears',
#  'global',
#  'growth',
#  'decelerates',
#  'wilson',
#  'expects',
#  'material',
#  'deceleration',
#  'corporate',
#  'profits',
#  'odds',
#  'strategists',
#  'expect',
#  'average',
#  'prediction',
#  'end',
#  'november',
#  'p',
#  '500',
#  'climb',
#  '3',
#  '056',
#  'end',
#  'next',
#  'year',
#  'according',
#  '14',
#  'forecasts',
#  'gathered',
#  'bloomberg',
#  'optimistic',
#  'year',
#  'ahead',
#  'call',
#  'since',
#  '2009',
#  'emerging',
#  'cheerjordi',
#  'visser',
#  'weiss',
#  'multi',
#  'strategy',
#  'advisers',
#  'predicted',
#  'peak',
#  'developing',
#  'market',
#  'rally',
#  'late',
#  'january',
#  'expects',
#  'emerging',
#  'markets',
#  'bright',
#  'spot',
#  '2019',
#  'dollar',
#  'stumbles',
#  'visser',
#  'calling',
#  'ishares',
#  'msci',
#  'emerging',
#  'markets',
#  'etf',
#  'nyse',
#  'eem',
#  'outperform',
#  'p',
#  '500',
#  'index',
#  '15',
#  'percent',
#  '20',
#  'percent',
#  '2019',
#  'chinese',
#  'internet',
#  'stocks',
#  'developing',
#  'nation',
#  'sovereign',
#  'debt',
#  'emerging',
#  'market',
#  'currencies',
#  'look',
#  'particularly',
#  'attractive',
#  'bullishness',
#  'comes',
#  'expectation',
#  'weaker',
#  'dollar',
#  'next',
#  'year',
#  'back',
#  'easier',
#  'u',
#  'monetary',
#  'policy',
#  'lag',
#  'recent',
#  'chinese',
#  'stimulus',
#  'measures',
#  'focus',
#  'value',
#  'factor',
#  '2019',
#  'rather',
#  'growth',
#  'said',
#  'new',
#  'york',
#  'based',
#  'visser',
#  'chief',
#  'investment',
#  'officer',
#  '1',
#  '7',
#  'billion',
#  'hedge',
#  'fund',
#  'tania',
#  'escobedo',
#  'strategist',
#  'rbc',
#  'capital',
#  'markets',
#  'llc',
#  'correctly',
#  'called',
#  'slide',
#  'brazilian',
#  'real',
#  'year',
#  'market',
#  'bullish',
#  'another',
#  'contrarian',
#  'call',
#  '2019',
#  'wagering',
#  'real',
#  'going',
#  'long',
#  'mexican',
#  'peso',
#  'investors',
#  'optimistic',
#  'brazil',
#  'incoming',
#  'government',
#  'concerned',
#  'populist',
#  'rhetoric',
#  'mexico',
#  'andres',
#  'manuel',
#  'lopez',
#  'obrador',
#  'pockets',
#  'value',
#  'emerging',
#  'markets',
#  'including',
#  'argentina',
#  'beaten',
#  'currency',
#  'lisa',
#  'chua',
#  'new',
#  'york',
#  'based',
#  'money',
#  'manager',
#  'man',
#  'glg',
#  'said',
#  'interview',
#  'last',
#  'month',
#  'firm',
#  'boasted',
#  'year',
#  'top',
#  'developing',
#  'nation',
#  'debt',
#  'fund',
#  '1',
#  'billion',
#  'management',
#  'according',
#  'data',
#  'compiled',
#  'bloomberg',
#  'trade',
#  'remindera',
#  'year',
#  'ago',
#  'jens',
#  'nordvig',
#  'exante',
#  'data',
#  'llc',
#  'cautioning',
#  'markets',
#  'adequately',
#  'priced',
#  'building',
#  'u',
#  'china',
#  'trade',
#  'dispute',
#  'concern',
#  'north',
#  'korea',
#  'nuclear',
#  'weapons',
#  'program',
#  'garnered',
#  'attention',
#  'expects',
#  'trade',
#  'tensions',
#  'remain',
#  'focal',
#  'point',
#  '2019',
#  'even',
#  'world',
#  'two',
#  'biggest',
#  'economies',
#  'appear',
#  'reached',
#  'tentative',
#  'truce',
#  'tariffs',
#  'china',
#  'try',
#  'delay',
#  'delay',
#  'NOTgive',
#  'big',
#  'stuff',
#  'said',
#  'nordvig',
#  'wall',
#  'street',
#  'top',
#  'ranked',
#  'currency',
#  'strategist',
#  'five',
#  'years',
#  'running',
#  'founding',
#  'exante',
#  'second',
#  'quarter',
#  'u',
#  'decide',
#  'agree',
#  'cosmetic',
#  'concessions',
#  'whether',
#  'actually',
#  'ready',
#  'sustained',
#  'trade',
#  'war']

# %%
# Separating the target
# y = df['sentiment'] 
X = df

X_train, X_test, y_train, y_test = train_test_split(X, y, 
                                                    random_state=42, 
                                                    test_size=0.3,
                                                    stratify=y)

print("X_train shape: ", X_train.shape)
print("X_test shape: ", X_test.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_123000/3389031582.py in <module>
#       3 X = df
#       4
# ----> 5 X_train, X_test, y_train, y_test = train_test_split(X, y,
#       6                                                     random_state=42,
#       7                                                     test_size=0.3,
#
# NameError: name 'y' is not defined

# %% [markdown]
# ### For sentiment analysis using unsupervised learning, we first train the word embedding model

# %%
# Training a Word2Vec model
keyed_vectors, keyed_vocab = w2v_trainer(df['tokenized_text'])

# %% [markdown]
# ### Then, we create positive and negative sets

# %%
# Find the most similar words to "good" 
keyed_vectors.most_similar('good',topn=15)
# Out:
# [('market', 0.9997321963310242),
#  ('would', 0.9997232556343079),
#  ('also', 0.9997193813323975),
#  ('u', 0.9997157454490662),
#  ('said', 0.9997138381004333),
#  ('markets', 0.9997131824493408),
#  ('reuters', 0.9997076988220215),
#  ('company', 0.999704122543335),
#  ('investors', 0.9997040033340454),
#  ('companies', 0.9997028708457947),
#  ('could', 0.9997027516365051),
#  ('global', 0.9997016191482544),
#  ('since', 0.9997003674507141),
#  ('one', 0.9996955394744873),
#  ('deal', 0.9996939897537231)]

# %%
# To make sure that all `positive_concepts` are in the keyed word2vec vocabulary
positive_concepts = ['excellent', 'awesome', 'cool','decent','amazing', 'strong', 'good', 'great', 'funny', 'entertaining'] 
pos_concepts = [concept for concept in positive_concepts if concept in keyed_vocab]

# %%
# Find the most similar words to "bad" 
keyed_vectors.most_similar('bad',topn=15)
# Out:
# [('could', 0.9992130994796753),
#  ('said', 0.9991994500160217),
#  ('reuters', 0.9991929531097412),
#  ('months', 0.9991893172264099),
#  ('markets', 0.9991881847381592),
#  ('billion', 0.9991803169250488),
#  ('would', 0.9991776347160339),
#  ('investors', 0.9991772770881653),
#  ('deal', 0.9991771578788757),
#  ('two', 0.999177098274231),
#  ('000', 0.9991746544837952),
#  ('tuesday', 0.9991728067398071),
#  ('china', 0.9991723299026489),
#  ('bank', 0.9991716146469116),
#  ('public', 0.9991708993911743)]

# %%
str(list(keyed_vocab.keys())[2000:3000])
# Out:
# "['setting', 'andrew', 'talk', 'lewis', 'richard', 'gone', 'dws', 'virus', 'jeff', 'buzzfeed', 'fitzgerald', 'withstand', 'exploitative', 'driver', 'titles', 'ms', 'bankers', 'lure', 'commodity', 'giant', 'figure', 'senator', 'bull', 'nine', 'releases', 'hikes', 'underpin', 'causing', 'packages', 'spark', 'imposing', 'virtually', 'bezos', 'correctly', 'upon', 'furukawa', 'bear', 'dependent', 'kicked', 'cic', 'suit', 'lisa', 'samarco', '280', 'vale', 'argentina', 'cemex', 'manuel', 'andres', 'latam', 'populist', 'damages', 'clh', '6870', 'treasuries', 'brazil', 'conconcret', 'nordvig', 'exante', 'etb', 'ipo', 'colcap', 'decide', 'founding', 'stuff', 'NOTsee', 'broad', 'tentative', 'daniel', 'adr', 'inched', 'alibaba', 'breaks', 'weapons', 'nuclear', 'baba', 'venture', 'wagering', 'shortages', 'mike', 'iamgold', 'img', 'material', '190', '920', 'troughs', '750', 'pessimism', 'gathered', 'adrs', 'towards', 'sogn', 'gauge', 'tighter', 'deceleration', 'via', 'climb', 'helping', 'brazilian', 'msci', 'factor', 'environmental', 'easier', 'attractive', 'pinduoduo', 'launching', 'etf', 'spot', 'discretionary', 'indicates', 'rises', 'preventing', 'cop', 'predicted', 'induced', '7974', 'comprehensive', '040', 'article', 'emerged', 'unclear', 'approve', 'argue', 'oceanwide', 'purchase', 'insurer', 'genworth', 'safeguard', 'professor', 'towson', 'ownership', 'bans', 'buyer', 'nov', 'divestment', 'untrusted', 'supreme', 'rights', 'affect', 'gig', 'unions', 'tend', 'worked', 'pimlico', 'negotiating', 'divest', 'amot', 'hallucinatory', 'neutral', 'advancers', 'bribe', 'confidant', 'telecoms', 'recommended', 'indicted', 'nir', 'sara', 'mandelblit', 'final', 'approached', 'echo', 'anything', 'anyone', 'filber', 'handler', 'controlled', 'eurocom', 'publisher', 'maintained', 'normal', 'vowed', 'runs', 'plumbers', 'dismissed', 'imposed', 'cards', 'entities', 'agreements', 'NOimmediate', 'NOfurther', 'required', 'stable', 'lifting', 'sweden', 'atlas', 'copco', 'fingerprint', 'fingb', 'perform', 'punishment', 'player', 'democracy', 'prize', 'commentators', 'brack', 'reacted', 'violated', 'relationships', 'urged', 'strongly', 'stability', 'improperly', 'arrangements', 'rabobank', 'reaching', 'apply', 'everyone', 'modern', 'bowl', 'wrote', 'expiration', 'generated', 'programming', 'watched', 'wave', 'forcing', 'seek', 'vans', 'wfc', 'pools', 'customer', 'citi', 'mount', 'headline', 'cause', 'damage', 'macquarie', 'bac', 'lynch', 'merrill', 'founder', '360', 'staf', 'solar', 'rgse', '3310', 'biocept', 'bioc', '121', '1551', '130', 'financier', 'hughes', 'walt', 'climate', 'writing', 'candidates', 'republicans', 'financially', 'taxing', 'assess', 'prohibited', 'rich', 'shot', 'great', 'staffing', 'ppl', 'ko', 'pg', 'attack', 'pound', 'eurofighter', 'built', 'consortium', 'charles', 'woodburn', 'commitments', 'land', 'digit', 'jefferies', 'morris', 'operational', 'ormat', 'ora', '420', 'paz', 'pzol', '1680', '49820', 'delek', 'procter', 'gamble', 'founded', 'dis', 'possibly', 'mmm', 'passed', 'jitters', 'pm', 'neighboring', 'whilst', 'check', 'cnbc', 'chipmakers', 'instruments', 'stm', '3m', 'pause', 'recently', 'tuz', 'NOTstop', 'consecutive', 'dji', 'spx', 'ixic', '108', 'philadelphia', 'semiconductor', 'edged', 'excited', 'hoping', 'books', 'decided', '3010', 'eventually', 'ore', 'abc', 'incitec', 'pivot', 'ipl', '070', 'aud', 'returns', '2013', 'pharmaceuticals', 'cvs', 'stalled', 'james', 'longtime', 'communication', 'managed', 'mediterranean', '8030', 'fisheries', '6050', 'arabian', 'cement', 'meddling', 'survive', 'adapting', 'events', 'chevron', 'hollyfrontier', 'hfc', 'losers', 'marathon', 'lyft', 'willis', 'trigger', 'host', 'preliminary', 'deadline', 'novgorod', 'mobil', 'russian', 'controls', 'extensions', 'NOTreply', 'rusal', 'powers', 'admits', 'outage', 'purchases', 'tweeted', 'NOTmake', 'xom', 'balyo', 'obviously', 'voted', 'bromwich', 'solihull', 'decisive', 'actions', 'confirmed', 'tanked', 'tobacco', 'effects', 'send', 'brokers', 'NOTal ...

# %%
str(sorted(keyed_vocab.items(), key=lambda item: item[0]))
# Out:
# "[('0', 1), ('00', 102), ('000', 76), ('002343', 2723), ('002439', 2720), ('01', 435), ('02', 376), ('03', 516), ('04', 471), ('040', 2117), ('05', 200), ('06', 672), ('060', 1749), ('07', 798), ('070', 2320), ('08', 482), ('09', 550), ('090', 1246), ('1', 2), ('10', 36), ('100', 329), ('104', 2753), ('106', 2500), ('108', 2305), ('11', 201), ('112', 2592), ('115', 1977), ('116', 1495), ('1170', 2520), ('12', 85), ('120', 1940), ('121', 2238), ('13', 250), ('130', 2240), ('133', 2864), ('14', 153), ('140', 542), ('15', 155), ('150', 2627), ('151', 1675), ('1551', 2239), ('16', 521), ('1680', 2277), ('17', 242), ('18', 355), ('180', 1289), ('19', 141), ('190', 2083), ('2', 7), ('20', 75), ('200', 382), ('2007', 2949), ('2008', 1107), ('201', 2508), ('2010', 1823), ('2011', 777), ('2013', 2323), ('2014', 622), ('2015', 468), ('2016', 533), ('2017', 299), ('2018', 205), ('2019', 127), ('2020', 320), ('2021', 1357), ('2022', 1775), ('2024', 2945), ('21', 265), ('22', 438), ('220', 2717), ('225', 1426), ('23', 149), ('230', 2494), ('232', 1695), ('24', 197), ('25', 209), ('250', 1432), ('26', 366), ('27', 362), ('270', 2715), ('28', 635), ('280', 2043), ('29', 375), ('295', 2524), ('3', 6), ('30', 87), ('300', 1263), ('301', 1690), ('3010', 2313), ('31', 232), ('32', 503), ('33', 331), ('3310', 2235), ('34', 457), ('349', 2974), ('35', 300), ('36', 599), ('360', 2231), ('37', 486), ('38', 539), ('380', 2439), ('39', 1250), ('3d', 2793), ('3m', 2296), ('4', 14), ('40', 72), ('41', 330), ('410', 2713), ('42', 534), ('420', 2274), ('43', 965), ('44', 432), ('45', 380), ('450', 2647), ('46', 410), ('47', 403), ('48', 494), ('49', 463), ('49820', 2278), ('5', 30), ('50', 158), ('500', 56), ('51', 929), ('52', 161), ('53', 739), ('54', 660), ('55', 239), ('56', 441), ('57', 809), ('58', 609), ('584', 2566), ('59', 789), ('6', 39), ('60', 294), ('600', 1099), ('6050', 2334), ('61', 560), ('62', 353), ('620', 1599), ('63', 951), ('64', 800), ('644', 2396), ('65', 673), ('66', 323), ('67', 508), ('68', 1182), ('6870', 2053), ('69', 943), ('7', 86), ('70', 453), ('700', 1319), ('71', 728), ('72', 510), ('73', 970), ('737', 2548), ('74', 1227), ('75', 342), ('750', 2086), ('755', 2650), ('76', 561), ('77', 546), ('78', 413), ('79', 1248), ('7974', 2115), ('8', 112), ('80', 183), ('800', 785), ('8030', 2332), ('81', 557), ('82', 558), ('83', 1087), ('84', 845), ('85', 456), ('851', 2444), ('86', 679), ('87', 1111), ('88', 332), ('89', 545), ('9', 106), ('90', 257), ('91', 1256), ('92', 705), ('920', 2084), ('93', 364), ('94', 415), ('95', 524), ('96', 616), ('97', 606), ('975', 2446), ('98', 1052), ('99', 835), ('NOTa', 1437), ('NOTall', 2379), ('NOTallow', 2676), ('NOTalready', 2966), ('NOTbe', 651), ('NOTbelieve', 1858), ('NOTclear', 1925), ('NOTgive', 1461), ('NOThave', 1488), ('NOTimmediately', 668), ('NOTmake', 2364), ('NOTonly', 1874), ('NOTprevent', 2669), ('NOTreply', 2357), ('NOTrequire', 2612), ('NOTrespond', 1485), ('NOTsee', 2065), ('NOTstop', 2300), ('NOTthe', 1607), ('NOTto', 2660), ('NOfurther', 2179), ('NOimmediate', 2178), ('a321neo', 2546), ('aal', 2778), ('aapl', 1326), ('ab', 446), ('abandoned', 2860), ('abc', 2316), ('ability', 1098), ('able', 725), ('abraxane', 1742), ('abroad', 2704), ('accepting', 2883), ('access', 526), ('accompanied', 2638), ('according', 69), ('account', 1524), ('accounts', 1443), ('accumulated', 2706), ('accused', 1023), ('accusing', 2763), ('achieve', 1774), ('acquire', 1035), ('acquired', 1398), ('acquisition', 2956), ('acquisitions', 872), ('across', 381), ('actares', 2601), ('action', 1308), ('actions', 2372), ('activist', 1245), ('activity', 480), ('adam', 2588), ('adapting', 2339), ('add', 770), ('added', 54), ('adding', 308), ('addition', 1679), ('additional', 608), ('address', 1213), ('adjusted', 1066), ('administration', 645), ('admits', 2360), ('admitted', 2744), ('adr', 2069), ('adrs', 2089), ('advanced', 1020), ('advancers', 2149), ('advances', 2736), ('advancing', 347), ('advantage', 14 ...

# %%
# To make sure that all `negative_concepts` are in the keyed word2vec vocabulary 
negative_concepts = ['terrible','awful','horrible','boring','bad', 'disappointing', 'weak', 'poor', 'senseless','confusing', 
                     'criminal', 'wrongdoing', 'fail', 'depressed', 'stress', 'frustrated', 'pessimistic', 'hopeless', 'worthless',
                     'cheating', 'concern', 'exit', 'exhausted', 'fear', 'fears', 'lost', 'worst', 'decline', 'fraud', 'warning', 
                     'pandemic', 'illegal', 'corruption', 'crisis', 'shutdown', 'slow', 'ban', 'attack', 'unfortunately',
                     'hurt', 'negative', 'panic', 'pullback', 'cancer', 'limit', 'uncertain', 'postponed', 'dirty', 'disease', 
                     'death', 'killed', 'dark', 'jitters', 'accused', 'dispute', 'losses', 'nervous', 'restrictions', 'fell', 
                    ] 
neg_concepts = [concept for concept in negative_concepts if concept in keyed_vocab]
len(negative_concepts)
# Out:
# 57

# %%
df['tokenized_text']
# Out:
# 0     [bloomberg, three, weeks, go, 2018, market, co...
# 1     [investing, com, colombia, stocks, higher, clo...
# 2     [investing, com, canada, stocks, lower, close,...
# 3     [washington, reuters, three, u, senators, thur...
# 4     [bloomberg, u, investors, looking, get, volati...
#                             ...
# 95    [investing, com, sweden, stocks, lower, close,...
# 96    [tel, aviv, reuters, salesforce, com, n, crm, ...
# 97    [investing, com, saudi, arabia, stocks, lower,...
# 98    [stephanie, nebehay, ryan, woogeneva, beijing,...
# 99    [investing, com, canada, stocks, lower, close,...
# Name: tokenized_text, Length: 100, dtype: object

# %%
df = df[df["tokenized_text"].notna()]

# %%
for ind, row in df.iterrows():
    if len(row['tokenized_text']) == 0:
        print(ind)

# %%
df.drop(index=[10599, 32703, 37590], inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_123000/2911684465.py in <module>
# ----> 1 df.drop(index=[10599, 32703, 37590], inplace=True)
#
# ~/.local/lib/python3.7/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~/.local/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4911             level=level,
#    4912             inplace=inplace,
# -> 4913             errors=errors,
#    4914         )
#    4915
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~/.local/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~/.local/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: '[10599 32703 37590] not found in axis'

# %%
# Calculating Semantic Sentiment Scores by OSSA model
overall_df_scores = overall_semantic_sentiment_analysis (keyed_vectors = keyed_vectors,
                                                   positive_target_tokens = pos_concepts, 
                                                   negative_target_tokens = neg_concepts,
                                                   doc_tokens = df['tokenized_text'])

# Calculating Semantic Sentiment Scores by TopSSA model
topn_df_scores = topn_semantic_sentiment_analysis (keyed_vectors = keyed_vectors,
                                                   positive_target_tokens = pos_concepts, 
                                                   negative_target_tokens = neg_concepts,
                                                   doc_tokens = df['tokenized_text'],
                                                     topn=30)


# To store semantic sentiment store computed by OSSA model in df
df['overall_PSS'] = overall_df_scores[0] 
df['overall_NSS'] = overall_df_scores[1] 
df['overall_semantic_sentiment_score'] = overall_df_scores[2] 
df['overall_semantic_sentiment_polarity'] = overall_df_scores[3]



# To store semantic sentiment store computed by TopSSA model in df
df['topn_PSS'] = topn_df_scores[0] 
df['topn_NSS'] = topn_df_scores[1] 
df['topn_semantic_sentiment_score'] = topn_df_scores[2] 
df['topn_semantic_sentiment_polarity'] = topn_df_scores[3]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_123000/940170725.py in <module>
#       1 # Calculating Semantic Sentiment Scores by OSSA model
#       2 overall_df_scores = overall_semantic_sentiment_analysis (keyed_vectors = keyed_vectors,
# ----> 3                                                    positive_target_tokens = pos_concepts,
#       4                                                    negative_target_tokens = neg_concepts,
#       5                                                    doc_tokens = df['tokenized_text'])
#
# NameError: name 'pos_concepts' is not defined

# %% [markdown]
# ### Test on long news data

# %%
news_text = "China’s stocks reversed course to rise Monday after data showing persistent deflationary pressures from weak domestic demand pushed them lower earlier in the session. Japan’s stocks jumped on growing bets that its central bank might not hike interest rates next week. November inflation numbers from China showed a faster-than-expected decline in consumer prices. The consumer price index fell 0.5% year-on-year, more than the 0.1% drop expected by economists polled by Reuters and the fastest slide since November 2020. The producer price index fell 3% year-on-year, compared with October’s 2.6% drop and expectations of a 2.8% decline. It also marked the 14th straight month of PPI decline and the quickest since August."

# %%
print(news_text)
# Out:
# China’s stocks reversed course to rise Monday after data showing persistent deflationary pressures from weak domestic demand pushed them lower earlier in the session. Japan’s stocks jumped on growing bets that its central bank might not hike interest rates next week. November inflation numbers from China showed a faster-than-expected decline in consumer prices. The consumer price index fell 0.5% year-on-year, more than the 0.1% drop expected by economists polled by Reuters and the fastest slide since November 2020. The producer price index fell 3% year-on-year, compared with October’s 2.6% drop and expectations of a 2.8% decline. It also marked the 14th straight month of PPI decline and the quickest since August.

# %%
tokenized_news = tokenizer.tokenize(news_text)

# %%
test = pd.DataFrame({"test": [tokenized_news]})

# %%
test
# Out:
#                                                 test
# 0  [china, stocks, reversed, course, rise, monday...

# %%
overall_df_scores = overall_semantic_sentiment_analysis (keyed_vectors = keyed_vectors,
                                                   positive_target_tokens = pos_concepts, 
                                                   negative_target_tokens = neg_concepts,
                                                   doc_tokens = test['test'])

# %%
overall_df_scores
# Out:
# (0    0.18017
#  Name: test, dtype: float32,
#  0    0.376213
#  Name: test, dtype: float32,
#  0   -0.196044
#  Name: test, dtype: float32,
#  0    0
#  Name: test, dtype: int64)
